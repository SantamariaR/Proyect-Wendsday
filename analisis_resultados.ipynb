# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_json("resultados/Wendsday_iteraciones.json")
print(df.head())

#Graficar ganancia Optuna eje x trial_number eje y ganancia
# Configurar el estilo
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(12, 6))

# Crear el gráfico
sns.lineplot(data=df, x='trial_number', y='value', marker='o', linewidth=2, markersize=6)

# Personalizar el gráfico
plt.title('Evolución de la Ganancia por Iteración de Optuna', fontsize=16, fontweight='bold')
plt.xlabel('Número de Trial', fontsize=12)
plt.ylabel('Ganancia', fontsize=12)
plt.grid(True, alpha=0.3)

# Formatear el eje y para mostrar valores en millones
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x/1e6:.1f}M'))

# Ajustar layout
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# Opcional: Mostrar estadísticas básicas
print(f"\nEstadísticas de ganancia:")
print(f"Ganancia máxima: {df['value'].max():,.0f}")
print(f"Ganancia mínima: {df['value'].min():,.0f}")
print(f"Ganancia promedio: {df['value'].mean():,.0f}")
print(f"Trial con mejor ganancia: {df.loc[df['value'].idxmax(), 'trial_number']}")
# Out:
#    trial_number                                             params      value  \
# 0             0  {'num_iterations': 2090, 'learning_rate': 0.00...  530672000
# 1             1  {'num_iterations': 2053, 'learning_rate': 0.01...  535684000
# 2             2  {'num_iterations': 2052, 'learning_rate': 0.00...  529032000
# 3             3  {'num_iterations': 2048, 'learning_rate': 0.00...  533780000
# 4             4  {'num_iterations': 2075, 'learning_rate': 0.00...  531420000
#
#                     datetime     state  \
# 0 2025-09-29 19:20:09.537212  COMPLETE
# 1 2025-09-29 19:20:59.746094  COMPLETE
# 2 2025-09-29 19:21:36.992080  COMPLETE
# 3 2025-09-29 19:22:33.965788  COMPLETE
# 4 2025-09-29 19:23:16.256336  COMPLETE
#
#                                        configuracion
# 0  {'semilla': 143287, 'mes_train': 202102, 'mes_...
# 1  {'semilla': 143287, 'mes_train': 202102, 'mes_...
# 2  {'semilla': 143287, 'mes_train': 202102, 'mes_...
# 3  {'semilla': 143287, 'mes_train': 202102, 'mes_...
# 4  {'semilla': 143287, 'mes_train': 202102, 'mes_...
# Estadísticas de ganancia:
# Ganancia máxima: 541,372,000
# Ganancia mínima: 345,780,000
# Ganancia promedio: 527,511,094
# Trial con mejor ganancia: 78
